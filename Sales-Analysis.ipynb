# %%
import pandas as pd
import os
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %% [markdown]
# ### merging 12 months of sales data in a single file

# %%
df = pd.read_csv('/Users/ashahwaka/Downloads/Sales_Data/Sales_April_2019.csv')

files = [file for file in os.listdir('/Users/ashahwaka/Downloads/Sales_Data')]
# create an empty data frame
all_months_data = pd.DataFrame()
for file in files:
    df = pd.read_csv('/Users/ashahwaka/Downloads/Sales_Data/'+file)
    all_months_data = pd.concat([all_months_data,df])
all_months_data.head()
all_months_data.to_csv("new_sales_data.csv",index=False)

# %%
df
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       209921        USB-C Charging Cable                1      11.95
# 1       209922          Macbook Pro Laptop                1     1700.0
# 2       209923             ThinkPad Laptop                1     999.99
# 3       209924            27in FHD Monitor                1     149.99
# 4       209925  Bose SoundSport Headphones                1      99.99
# ...        ...                         ...              ...        ...
# 13617   222905      AAA Batteries (4-pack)                1       2.99
# 13618   222906            27in FHD Monitor                1     149.99
# 13619   222907        USB-C Charging Cable                1      11.95
# 13620   222908        USB-C Charging Cable                1      11.95
# 13621   222909      AAA Batteries (4-pack)                1       2.99
#
#            Order Date                       Purchase Address
# ...

# %% [markdown]
# # Read updated data

# %%
new_data = pd.read_csv('/Users/ashahwaka/new_sales_data.csv')
new_data.head()
# Out:
#   Order ID               Product Quantity Ordered Price Each      Order Date  \
# 0   295665    Macbook Pro Laptop                1       1700  12/30/19 00:01
# 1   295666    LG Washing Machine                1      600.0  12/29/19 07:03
# 2   295667  USB-C Charging Cable                1      11.95  12/12/19 18:21
# 3   295668      27in FHD Monitor                1     149.99  12/22/19 15:13
# 4   295669  USB-C Charging Cable                1      11.95  12/18/19 12:38
#
#                          Purchase Address
# 0  136 Church St, New York City, NY 10001
# 1     562 2nd St, New York City, NY 10001
# 2    277 Main St, New York City, NY 10001
# 3     410 6th St, San Francisco, CA 94016
# 4           43 Hill St, Atlanta, GA 30301

# %% [markdown]
# # clean up the data

# %%
new_data.isnull().sum()
# Out:
# Order ID            545
# Product             545
# Quantity Ordered    545
# Price Each          545
# Order Date          545
# Purchase Address    545
# dtype: int64

# %%
new_data = new_data.dropna()

# %%
new_data.head()
# Out:
#   Order ID               Product Quantity Ordered Price Each      Order Date  \
# 0   295665    Macbook Pro Laptop                1       1700  12/30/19 00:01
# 1   295666    LG Washing Machine                1      600.0  12/29/19 07:03
# 2   295667  USB-C Charging Cable                1      11.95  12/12/19 18:21
# 3   295668      27in FHD Monitor                1     149.99  12/22/19 15:13
# 4   295669  USB-C Charging Cable                1      11.95  12/18/19 12:38
#
#                          Purchase Address
# 0  136 Church St, New York City, NY 10001
# 1     562 2nd St, New York City, NY 10001
# 2    277 Main St, New York City, NY 10001
# 3     410 6th St, San Francisco, CA 94016
# 4           43 Hill St, Atlanta, GA 30301

# %% [markdown]
# # Augment the data with additional columns

# %% [markdown]
# ### Task 2 Add months data

# %%
new_data.dtypes
# Out:
# Order ID            object
# Product             object
# Quantity Ordered    object
# Price Each          object
# Order Date          object
# Purchase Address    object
# dtype: object

# %%
new_data['Order Date']
# Out:
# 0         12/30/19 00:01
# 1         12/29/19 07:03
# 2         12/12/19 18:21
# 3         12/22/19 15:13
# 4         12/18/19 12:38
#                ...
# 186845    06/07/19 19:02
# 186846    06/01/19 19:29
# 186847    06/22/19 18:57
# 186848    06/26/19 18:35
# 186849    06/25/19 14:33
# Name: Order Date, Length: 186305, dtype: object

# %%
new_data['Order Date'] = pd.to_datetime(new_data['Order Date'],errors='coerce')
# Out:
# /var/folders/0x/8mzn531s42xf4x89nq4bydbw0000gn/T/ipykernel_19126/2800282786.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   new_data['Order Date'] = pd.to_datetime(new_data['Order Date'],errors='coerce')

# %%
new_data.head()
# Out:
#   Order ID               Product Quantity Ordered Price Each  \
# 0   295665    Macbook Pro Laptop                1       1700
# 1   295666    LG Washing Machine                1      600.0
# 2   295667  USB-C Charging Cable                1      11.95
# 3   295668      27in FHD Monitor                1     149.99
# 4   295669  USB-C Charging Cable                1      11.95
#
#            Order Date                        Purchase Address
# 0 2019-12-30 00:01:00  136 Church St, New York City, NY 10001
# 1 2019-12-29 07:03:00     562 2nd St, New York City, NY 10001
# 2 2019-12-12 18:21:00    277 Main St, New York City, NY 10001
# 3 2019-12-22 15:13:00     410 6th St, San Francisco, CA 94016
# 4 2019-12-18 12:38:00           43 Hill St, Atlanta, GA 30301

# %%
new_data.tail()
# Out:
#        Order ID                 Product Quantity Ordered Price Each  \
# 186845   222905  AAA Batteries (4-pack)                1       2.99
# 186846   222906        27in FHD Monitor                1     149.99
# 186847   222907    USB-C Charging Cable                1      11.95
# 186848   222908    USB-C Charging Cable                1      11.95
# 186849   222909  AAA Batteries (4-pack)                1       2.99
#
#                 Order Date                       Purchase Address
# 186845 2019-06-07 19:02:00          795 Pine St, Boston, MA 02215
# 186846 2019-06-01 19:29:00  495 North St, New York City, NY 10001
# 186847 2019-06-22 18:57:00  319 Ridge St, San Francisco, CA 94016
# 186848 2019-06-26 18:35:00   916 Main St, San Francisco, CA 94016
# 186849 2019-06-25 14:33:00         209 11th St, Atlanta, GA 30301

# %% [markdown]
# # Task 3; Add a sales column

# %%
new_data.dtypes
# Out:
# Order ID                    object
# Product                     object
# Quantity Ordered            object
# Price Each                  object
# Order Date          datetime64[ns]
# Purchase Address            object
# dtype: object

# %% [markdown]
# ## convert columns to the correct type

# %%
new_data['Order Date'] = new_data['Order Date'].fillna(0)
row_254 = new_data.iloc[254]
print(row_254)
# Out:
# Order ID                    Order ID
# Product                      Product
# Quantity Ordered    Quantity Ordered
# Price Each                Price Each
# Order Date                         0
# Purchase Address    Purchase Address
# Name: 254, dtype: object

# %%
invalid_rows = new_data[~new_data['Quantity Ordered'].str.isnumeric()]
print(invalid_rows)
# Out:
#         Order ID  Product  Quantity Ordered  Price Each Order Date  \
# 254     Order ID  Product  Quantity Ordered  Price Each          0
# 705     Order ID  Product  Quantity Ordered  Price Each          0
# 1101    Order ID  Product  Quantity Ordered  Price Each          0
# 2875    Order ID  Product  Quantity Ordered  Price Each          0
# 3708    Order ID  Product  Quantity Ordered  Price Each          0
# ...          ...      ...               ...         ...        ...
# 183671  Order ID  Product  Quantity Ordered  Price Each          0
# 184012  Order ID  Product  Quantity Ordered  Price Each          0
# 184041  Order ID  Product  Quantity Ordered  Price Each          0
# 184275  Order ID  Product  Quantity Ordered  Price Each          0
# 186532  Order ID  Product  Quantity Ordered  Price Each          0
#
#         Purchase Address
# 254     Purchase Address
# 705     Purchase Address
# 1101    Purchase Address
# 2875    Purchase Address
# 3708    Purchase Address
# ...

# %%
new_data = new_data[new_data['Order ID'] != 'Order ID']

# %%
new_data['Quantity Ordered'] = pd.to_numeric(new_data['Quantity Ordered'], errors='coerce')

# %%
new_data['Price Each'] = pd.to_numeric(new_data['Price Each'], errors='coerce')

# %%
new_data = new_data.dropna()

# %%
new_data['Quantity Ordered'] = pd.to_numeric(new_data['Quantity Ordered'])

# %%
new_data['Price Each'] = pd.to_numeric(new_data['Price Each'])

# %%
new_data.head()
# Out:
#   Order ID               Product  Quantity Ordered  Price Each  \
# 0   295665    Macbook Pro Laptop                 1     1700.00
# 1   295666    LG Washing Machine                 1      600.00
# 2   295667  USB-C Charging Cable                 1       11.95
# 3   295668      27in FHD Monitor                 1      149.99
# 4   295669  USB-C Charging Cable                 1       11.95
#
#             Order Date                        Purchase Address
# 0  2019-12-30 00:01:00  136 Church St, New York City, NY 10001
# 1  2019-12-29 07:03:00     562 2nd St, New York City, NY 10001
# 2  2019-12-12 18:21:00    277 Main St, New York City, NY 10001
# 3  2019-12-22 15:13:00     410 6th St, San Francisco, CA 94016
# 4  2019-12-18 12:38:00           43 Hill St, Atlanta, GA 30301

# %%
new_data['Order Date'] = pd.to_datetime(new_data['Order Date'])

# %%
new_data['Months'] = new_data['Order Date'].dt.month.fillna(0).astype('int32')

# %%
new_data['Total Sales'] = new_data['Quantity Ordered'] * new_data['Price Each']

# %%
new_data.head()
# Out:
#   Order ID               Product  Quantity Ordered  Price Each  \
# 0   295665    Macbook Pro Laptop                 1     1700.00
# 1   295666    LG Washing Machine                 1      600.00
# 2   295667  USB-C Charging Cable                 1       11.95
# 3   295668      27in FHD Monitor                 1      149.99
# 4   295669  USB-C Charging Cable                 1       11.95
#
#            Order Date                        Purchase Address  Months  \
# 0 2019-12-30 00:01:00  136 Church St, New York City, NY 10001      12
# 1 2019-12-29 07:03:00     562 2nd St, New York City, NY 10001      12
# 2 2019-12-12 18:21:00    277 Main St, New York City, NY 10001      12
# 3 2019-12-22 15:13:00     410 6th St, San Francisco, CA 94016      12
# 4 2019-12-18 12:38:00           43 Hill St, Atlanta, GA 30301      12
#
#    Total Sales
# 0      1700.00
# 1       600.00
# 2        11.95
# 3       149.99
# 4        11.95

# %% [markdown]
# # What was the best month for sales? How much was earned that month?

# %%
results = new_data.groupby('Months').sum(numeric_only=True)
# new_data['Months'].dtypes
results
# Out:
#         Quantity Ordered  Price Each  Total Sales
# Months
# 1                  10903  1811768.38   1822256.73
# 2                  13449  2188884.72   2202022.42
# 3                  17005  2791207.83   2807100.38
# 4                  20558  3367671.02   3390670.24
# 5                  18667  3135125.13   3152606.75
# 6                  15253  2562025.61   2577802.26
# 7                  16072  2632539.56   2647775.76
# 8                  13448  2230345.42   2244467.88
# 9                  13109  2084992.09   2097560.13
# 10                 22703  3715554.83   3736726.88
# 11                 19798  3180600.68   3199603.20
# 12                 28114  4588415.41   4613443.34

# %%
import matplotlib.pyplot as plt

# %%
months = range(1,13)
plt.bar(months,results['Total Sales'])
plt.xticks(months)
plt.ylabel('Sales in usd ($)')
plt.xlabel('Month Number')
plt.title('Total Sales Against Months')
plt.show()

# %% [markdown]
# # What US City has the highest number of sales

# %%
new_data.head(2)
# Out:
#   Order ID             Product  Quantity Ordered  Price Each  \
# 0   295665  Macbook Pro Laptop                 1      1700.0
# 1   295666  LG Washing Machine                 1       600.0
#
#            Order Date                        Purchase Address  Months  \
# 0 2019-12-30 00:01:00  136 Church St, New York City, NY 10001      12
# 1 2019-12-29 07:03:00     562 2nd St, New York City, NY 10001      12
#
#    Total Sales
# 0       1700.0
# 1        600.0

# %%
def get_city(address):
    return address.split(',')[1]
def get_state(address):
    return address.split(',')[2].split(' ')[1]
new_data['City'] = new_data['Purchase Address'].apply(lambda x: get_city(x) + ' (' + get_state(x) + ')')

# %%
new_data.head()
# Out:
#   Order ID               Product  Quantity Ordered  Price Each  \
# 0   295665    Macbook Pro Laptop                 1     1700.00
# 1   295666    LG Washing Machine                 1      600.00
# 2   295667  USB-C Charging Cable                 1       11.95
# 3   295668      27in FHD Monitor                 1      149.99
# 4   295669  USB-C Charging Cable                 1       11.95
#
#            Order Date                        Purchase Address  Months  \
# 0 2019-12-30 00:01:00  136 Church St, New York City, NY 10001      12
# 1 2019-12-29 07:03:00     562 2nd St, New York City, NY 10001      12
# 2 2019-12-12 18:21:00    277 Main St, New York City, NY 10001      12
# 3 2019-12-22 15:13:00     410 6th St, San Francisco, CA 94016      12
# 4 2019-12-18 12:38:00           43 Hill St, Atlanta, GA 30301      12
#
#    Total Sales                 City
# 0      1700.00   New York City (NY)
# 1       600.00   New York City (NY)
# 2        11.95   New York City (NY)
# ...

# %% [markdown]
# # city with highest number of sales

# %%
results = new_data.groupby('City').sum(numeric_only=True)
results
# Out:
#                     Quantity Ordered  Price Each  Months  Total Sales
# City
# Atlanta (GA)                   16602  2779908.20  104794   2795498.58
# Austin (TX)                    11153  1809873.61   69829   1819581.75
# Boston (MA)                    22528  3637409.77  141112   3661642.01
# Dallas (TX)                    16730  2752627.82  104620   2767975.40
# Los Angeles (CA)               33289  5421435.23  208325   5452570.80
# New York City (NY)             27932  4635370.83  175741   4664317.43
# Portland (ME)                   2750   447189.25   17144    449758.27
# Portland (OR)                  11303  1860558.22   70621   1870732.34
# San Francisco (CA)             50239  8211461.74  315520   8262203.91
# Seattle (WA)                   16553  2733296.01  104941   2747755.48

# %%
cities = [city for city, df in new_data.groupby('City')]
cities
plt.bar(cities,results['Total Sales'])
plt.xticks(cities,rotation='vertical', size=8)
plt.ylabel('Sales in usd ($)')
plt.xlabel('City Name')
plt.title('Total Sales Per City')
plt.show()

# %% [markdown]
# # What time should we display the advertisement to maximize the likelihood of customers buying the products

# %%
new_data.head(2)
# Out:
#   Order ID             Product  Quantity Ordered  Price Each  \
# 0   295665  Macbook Pro Laptop                 1      1700.0
# 1   295666  LG Washing Machine                 1       600.0
#
#            Order Date                        Purchase Address  Months  \
# 0 2019-12-30 00:01:00  136 Church St, New York City, NY 10001      12
# 1 2019-12-29 07:03:00     562 2nd St, New York City, NY 10001      12
#
#    Total Sales                 City
# 0       1700.0   New York City (NY)
# 1        600.0   New York City (NY)

# %%
new_data.dtypes
# Out:
# Order ID                    object
# Product                     object
# Quantity Ordered             int64
# Price Each                 float64
# Order Date          datetime64[ns]
# Purchase Address            object
# Months                       int32
# Total Sales                float64
# City                        object
# dtype: object

# %%
new_data['Hour'] = new_data['Order Date'].dt.hour

# %%
new_data['Minute'] = new_data['Order Date'].dt.minute

# %%
new_data.head()
# Out:
#   Order ID               Product  Quantity Ordered  Price Each  \
# 0   295665    Macbook Pro Laptop                 1     1700.00
# 1   295666    LG Washing Machine                 1      600.00
# 2   295667  USB-C Charging Cable                 1       11.95
# 3   295668      27in FHD Monitor                 1      149.99
# 4   295669  USB-C Charging Cable                 1       11.95
#
#            Order Date                        Purchase Address  Months  \
# 0 2019-12-30 00:01:00  136 Church St, New York City, NY 10001      12
# 1 2019-12-29 07:03:00     562 2nd St, New York City, NY 10001      12
# 2 2019-12-12 18:21:00    277 Main St, New York City, NY 10001      12
# 3 2019-12-22 15:13:00     410 6th St, San Francisco, CA 94016      12
# 4 2019-12-18 12:38:00           43 Hill St, Atlanta, GA 30301      12
#
#    Total Sales                 City  Hour  Minute
# 0      1700.00   New York City (NY)     0       1
# 1       600.00   New York City (NY)     7       3
# ...

# %%
 new_data.groupby('Hour').count() #use of count
# Out:
#       Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# Hour
# 0         3910     3910              3910        3910        3910
# 1         2350     2350              2350        2350        2350
# 2         1243     1243              1243        1243        1243
# 3          831      831               831         831         831
# 4          854      854               854         854         854
# 5         1321     1321              1321        1321        1321
# 6         2482     2482              2482        2482        2482
# 7         4011     4011              4011        4011        4011
# 8         6256     6256              6256        6256        6256
# 9         8748     8748              8748        8748        8748
# 10       10944    10944             10944       10944       10944
# 11       12411    12411             12411       12411       12411
# 12       12587    12587             12587       12587       12587
# ...

# %%
hours = [hour for hour, df in new_data.groupby('Hour')]
plt.plot(hours,new_data.groupby('Hour').count())
plt.xticks(hours)
plt.grid()
plt.xlabel('Hours')
plt.ylabel('Number of Orders')
plt.title('Number of Sales against time')
plt.show()

# %%
# use of sum
new_data.groupby('Hour')['Total Sales'].sum()
# Out:
# Hour
# 0      713721.27
# 1      460866.88
# 2      234851.44
# 3      145757.89
# 4      162661.01
# 5      230679.82
# 6      448113.00
# 7      744854.12
# 8     1192348.97
# 9     1639030.58
# 10    1944286.77
# 11    2300610.24
# 12    2316821.34
# 13    2155389.80
# 14    2083672.73
# 15    1941549.60
# 16    1904601.31
# 17    2129361.61
# 18    2219348.30
# 19    2412938.54
# 20    2281716.24
# 21    2042000.86
# 22    1607549.21
# 23    1179304.44
# Name: Total Sales, dtype: float64

# %% [markdown]
# # What products are most often sold together

# %%
 new_data.head(2)
# Out:
#   Order ID             Product  Quantity Ordered  Price Each  \
# 0   295665  Macbook Pro Laptop                 1      1700.0
# 1   295666  LG Washing Machine                 1       600.0
#
#            Order Date                        Purchase Address  Months  \
# 0 2019-12-30 00:01:00  136 Church St, New York City, NY 10001      12
# 1 2019-12-29 07:03:00     562 2nd St, New York City, NY 10001      12
#
#    Total Sales                 City  Hour  Minute
# 0       1700.0   New York City (NY)     0       1
# 1        600.0   New York City (NY)     7       3

# %%
 df = new_data[new_data['Order ID'].duplicated(keep=False)]
df['Grouped'] = df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
df.head()
# Out:
# /var/folders/0x/8mzn531s42xf4x89nq4bydbw0000gn/T/ipykernel_19126/2135812610.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Grouped'] = df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 16   295681                Google Phone                 1      600.00
# 17   295681        USB-C Charging Cable                 1       11.95
# 18   295681  Bose SoundSport Headphones                 1       99.99
# 19   295681            Wired Headphones                 1       11.99
# 36   295698             Vareebadd Phone                 1      400.00
#
#             Order Date                     Purchase Address  Months  \
# ...

# %%
  df = df[['Order ID','Grouped']].drop_duplicates()
df.head()
# Out:
#    Order ID                                            Grouped
# 16   295681  Google Phone,USB-C Charging Cable,Bose SoundSp...
# 36   295698               Vareebadd Phone,USB-C Charging Cable
# 42   295703   AA Batteries (4-pack),Bose SoundSport Headphones
# 66   295726                    iPhone,Lightning Charging Cable
# 76   295735   iPhone,Apple Airpods Headphones,Wired Headphones

# %%
from itertools import combinations
from collections import Counter

# %%
count = Counter()
for row in df['Grouped']:
    row_list = row.split(',')
    count.update(Counter(combinations(row_list,2)))
for key,value in count.most_common(10):
    print(key,value)
# Out:
# ('iPhone', 'Lightning Charging Cable') 1005
# ('Google Phone', 'USB-C Charging Cable') 987
# ('iPhone', 'Wired Headphones') 447
# ('Google Phone', 'Wired Headphones') 414
# ('Vareebadd Phone', 'USB-C Charging Cable') 361
# ('iPhone', 'Apple Airpods Headphones') 360
# ('Google Phone', 'Bose SoundSport Headphones') 220
# ('USB-C Charging Cable', 'Wired Headphones') 160
# ('Vareebadd Phone', 'Wired Headphones') 143
# ('Lightning Charging Cable', 'Wired Headphones') 92

# %% [markdown]
#  # What product sold the most?Why do you think so?

# %%
new_data.head(2)
# Out:
#   Order ID             Product  Quantity Ordered  Price Each  \
# 0   295665  Macbook Pro Laptop                 1      1700.0
# 1   295666  LG Washing Machine                 1       600.0
#
#            Order Date                        Purchase Address  Months  \
# 0 2019-12-30 00:01:00  136 Church St, New York City, NY 10001      12
# 1 2019-12-29 07:03:00     562 2nd St, New York City, NY 10001      12
#
#    Total Sales                 City  Hour  Minute
# 0       1700.0   New York City (NY)     0       1
# 1        600.0   New York City (NY)     7       3

# %%
product_group = new_data.groupby('Product')
Quantity_ordered = product_group.sum(numeric_only=True)['Quantity Ordered'] 

products = [product for product,df in product_group]
plt.bar(products,Quantity_ordered)
plt.xticks(products,rotation='vertical', size=8)
plt.ylabel('Quantity Ordered')
plt.xlabel('Product')
plt.title('Product against Quantity')
plt.show()

# %%
prices = new_data.groupby('Product')['Price Each'].mean()
prices
# Out:
# Product
# 20in Monitor                   109.99
# 27in 4K Gaming Monitor         389.99
# 27in FHD Monitor               149.99
# 34in Ultrawide Monitor         379.99
# AA Batteries (4-pack)            3.84
# AAA Batteries (4-pack)           2.99
# Apple Airpods Headphones       150.00
# Bose SoundSport Headphones      99.99
# Flatscreen TV                  300.00
# Google Phone                   600.00
# LG Dryer                       600.00
# LG Washing Machine             600.00
# Lightning Charging Cable        14.95
# Macbook Pro Laptop            1700.00
# ThinkPad Laptop                999.99
# USB-C Charging Cable            11.95
# Vareebadd Phone                400.00
# Wired Headphones                11.99
# iPhone                         700.00
# Name: Price Each, dtype: float64

# %%
prices = new_data.groupby('Product')['Price Each'].mean()

fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.bar(products, Quantity_ordered,color='g')
ax2.plot(products,prices,'b-')

ax1.set_xlabel('Product Name')
ax1.set_ylabel('Quantity ordered',color='g')
ax2.set_ylabel('price ($)', color = 'b')
ax1.set_xticklabels(products, rotation='vertical',size=8)
plt.show()
# Out:
# /var/folders/0x/8mzn531s42xf4x89nq4bydbw0000gn/T/ipykernel_19126/805405333.py:12: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(products, rotation='vertical',size=8)
